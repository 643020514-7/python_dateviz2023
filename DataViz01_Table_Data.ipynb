# %% [markdown]
# <a href="https://colab.research.google.com/github/643020514-7/python_dateviz2023/blob/main/DataViz01_Table_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://datavizcatalogue.com

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df['Name'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ![iris-dataset.png](data:image/png;base64,...)

# %% [markdown]
# # Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df, 'Name')
# Out:
# <Axes: >

# %% [markdown]
# ### select columns to show

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength','PetalLength'])
# Out:
# <Axes: >

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength','PetalLength','SepalWidth','PetalWidth'])
# Out:
# <Axes: >

# %% [markdown]
# ### change color
#
# https://matplotlib.org/stable/tutorials/colors/colors.html

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=['c','m','y'])
# Out:
# <Axes: >

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.4,0,0],[1,1,0],[0.2,0.4,0.7,0.5]])
# Out:
# <Axes: >

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=['#FF00E0', '#00FFE2', '#88B46C'])
# Out:
# <Axes: >

# %% [markdown]
# ### Specify color by colormap
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
pd.plotting.parallel_coordinates(df, 'Name', colormap='magma')
# Out:
# <Axes: >

# %% [markdown]
# # Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib

# %%
import numpy as np

# %% [markdown]
# ## Heatmap matrix

# %%
matplotlib.rcParams['figure.figsize']=[30,5] #กำหนดขนาดของ figure
plt.imshow(np.array(df.iloc[:,:-1]).T,interpolation='nearest')

# %%
plt.imshow(df.iloc[:,:-1],interpolation='nearest',cmap = 'hot')

# %% [markdown]
# ## Subplot
# ###เอาplotมารวมกัน

# %%
matplotlib.rcParams['figure.figsize']=[20,5] #ปรับขนาด

# %%
plt.subplot(1,3,1)  # subplot(มีกี่แถว, มีกี่หลัก, เป็นตัวที่เท่าไหร่)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest')

plt.subplot(1,3,2)
plt.imshow(df.iloc[50:100,:-1],interpolation='nearest')

plt.subplot(1,3,3)
plt.imshow(df.iloc[100:150,:-1],interpolation='nearest')

# %%
plt.subplot(1,3,1)  # subplot(มีกี่แถว, มีกี่หลัก, เป็นตัวที่เท่าไหร่)
plt.imshow(np.array(df.iloc[:50,:-1]).T,interpolation='nearest',cmap='gist_heat')

plt.subplot(1,3,2)
plt.imshow(df.iloc[50:100,:-1],interpolation='nearest',cmap='afmhot')

plt.subplot(1,3,3)
plt.imshow(df.iloc[100:150,:-1],interpolation='nearest',cmap='hot')

# %%
matplotlib.rcParams['figure.figsize']=[20,5]
plt.subplot(1,4,2)
plt.imshow(df.iloc[50:100,:-1],interpolation='nearest',alpha = 0.8)

plt.subplot(1,4,1)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot')

plt.subplot(1,4,2)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot',alpha = 0.6)

plt.subplot(1,4,3)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot',alpha = 0.5)

plt.subplot(1,4,4)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot',alpha = 0.8)

# %%
matplotlib.rcParams['figure.figsize']=[20,5]
plt.subplot(1,2,1)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]])

plt.subplot(1,2,2)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5],[0,0,0.8],[0.2,0.4,0.7]])
# Out:
# <Axes: >

# %%
matplotlib.rcParams['figure.figsize']=[20,5]
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]])
# Out:
# <Axes: >

# %% [markdown]
# ## HW3
#
# วาดกราฟ parallel coordinate เปรียบเทียบ [ราคา และ พื้นที่ใช้สอย] ของบ้านและคอนโดในจังหวัดเชียงใหม่

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-21-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
unit = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_unittype.csv')
unit.head()

# %%
project = pd.read_csv('/content/drive/MyDrive/BPDV65/opendata_project.csv')
project.head()

# %%
project.columns

# %% [markdown]
# # ต่อตาราง

# %%
project_nodup = project.drop_duplicates(subset=['project_id'])

unit['province'] = unit['project_id'].map(project_nodup.set_index('project_id')['province_name_th'])
unit.head()

# %%
unit_cm = unit[unit['province']=='เชียงใหม่']
unit_cm

# %%
unit_cm_hcd = unit_cm[(unit_cm['propertytype_name_en']=='Condo') | (unit_cm['propertytype_name_en']=='Detached House')]
unit_cm_hcd.head()

# %%
unit_cm_hcd = unit_cm_hcd.dropna(subset=['price_min','area_usable_min'])

# %%
unit_cm_hcd['area_usable_min'] = unit_cm_hcd['area_usable_min'].apply(lambda x: x*100000)

# %%
matplotlib.rcParams['figure.figsize']=[12,12]

# %%
pd.plotting.parallel_coordinates(unit_cm_hcd, 'propertytype_name_en', cols = ['price_min','area_usable_min'],color=[[1,0,0,0.3],[0,0,1,1]])

# %% [markdown]
# #Quiz 4

# %%
plt.subplot(1,3,1)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='gist_heat')

plt.subplot(1,3,2)
plt.imshow(df.iloc[50:100,:-1],interpolation='nearest',cmap='afmhot')

plt.subplot(1,3,3)
plt.imshow(df.iloc[100:150,:-1],interpolation='nearest',cmap='hot')

# %% [markdown]
# 643020514-7

# %%
50%7 #ใช้เลข 1
# Out:
# 1

# %%
plt.subplot(3,1,1)  # subplot(มีกี่แถว, มีกี่หลัก, เป็นตัวที่เท่าไหร่)
plt.imshow(np.array(df.iloc[:1,:-1]).T,interpolation='nearest',cmap='gist_heat')

plt.subplot(3,1,2)
plt.imshow(np.array(df.iloc[:1,:-1]).T,interpolation='nearest',cmap='afmhot')

plt.subplot(3,1,3)
plt.imshow(np.array(df.iloc[:1,:-1]).T,interpolation='nearest',cmap='hot')
